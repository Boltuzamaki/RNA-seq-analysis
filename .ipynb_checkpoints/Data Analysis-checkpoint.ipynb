# %% [markdown]
# # First lets see how data looks like in Phantasus

# %%
from IPython.display import Image
Image(filename='data.PNG')

# %% [markdown]
# # Thought after observing the dataset at first glance
#
# ### The above picture is divided into two parts
# - The upper part have rows listed in left side and second part rows listed on right side.
#
# - The first part is a other info of person in which columns are participant ids and column contains various meta data of that persons.Also each info have different categories of value which we can see by hovering mouse over it.
#
# - The second part is the RNA sequencing reads of different persons.

# %% [markdown]
# # Loading libraries

# %%
from cmapPy.pandasGEXpress.parse_gct import parse
from cmapPy.pandasGEXpress.write_gct import write
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Loading the dataset and further oberving the dataset

# %%
data = parse('PAAD.gct')

# %% [markdown]
# ### Lets check the metadata hidden in rows and columns

# %%
data.row_metadata_df     # No metadata of rows(RNA ids)
# Out:
# Empty DataFrame
# Columns: []
# Index: [SLC35E2, A1BG, A1CF, A2BP1, A2LD1, A2ML1, A2M, A4GALT, A4GNT, AAA1, AAAS, AACSL, AACS, AADAC, AADAT, AAGAB, AAK1, AAMP, AANAT, AARS2, AARSD1, AARS, AASDHPPT, AASDH, AASS, AATF, AATK, ABAT, ABCA10, ABCA11P, ABCA12, ABCA13, ABCA17P, ABCA1, ABCA2, ABCA3, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCB10, ABCB11, ABCB1, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC10, ABCC11, ABCC13, ABCC1, ABCC2, ABCC3, ABCC4, ABCC5, ABCC6P1, ABCC6P2, ABCC6, ABCC8, ABCC9, ABCD1, ABCD2, ABCD3, ABCD4, ABCE1, ABCF1, ABCF2, ABCF3, ABCG1, ABCG2, ABCG4, ABCG5, ABCG8, ABHD10, ABHD11, ABHD12B, ABHD12, ABHD13, ABHD14A, ABHD14B, ABHD15, ABHD1, ABHD2, ABHD3, ABHD4, ABHD5, ABHD6, ABHD8, ABI1, ABI2, ABI3BP, ABI3, ABL1, ABL2, ABLIM1, ABLIM2, ...]
#
# [18465 rows x 0 columns]

# %%
data.col_metadata_df  # There is the hidden metadata of columns which we were getting on Phantasus when we
                      # were hovering mouse over it
# Out:
# chd                      participant_id          sample_type  mRNAseq_cluster  \
# cid
# aab1-Primary solid Tumor           aab1  Primary solid Tumor              1.0
# aab4-Primary solid Tumor           aab4  Primary solid Tumor              2.0
# aab6-Primary solid Tumor           aab6  Primary solid Tumor              3.0
# aab8-Primary solid Tumor           aab8  Primary solid Tumor              1.0
# aab9-Primary solid Tumor           aab9  Primary solid Tumor              4.0
# ...                                 ...                  ...              ...
# a89d-Solid Tissue Normal           a89d  Solid Tissue Normal              NaN
# a89d-Primary solid Tumor           a89d  Primary solid Tumor              2.0
# a8sy-Primary solid Tumor           a8sy  Primary solid Tumor              3.0
# a8lh-Primary solid Tumor           a8lh  Primary solid Tumor              1.0
# aapl-Primary solid Tumor           aapl  Primary solid Tumor              5.0
#
# chd                      bcr_patient_barcode  \
# cid
# aab1-Primary solid Tumor        tcga-2j-aab1
# aab4-Primary solid Tumor        tcga-2j-aab4
# aab6-Primary solid Tumor        tcga-2j-aab6
# aab8-Primary solid Tumor        tcga-2j-aab8
# aab9-Primary solid Tumor        tcga-2j-aab9
# ...                                      ...
# a89d-Solid Tissue Normal        tcga-yb-a89d
# a89d-Primary solid Tumor        tcga-yb-a89d
# a8sy-Primary solid Tumor        tcga-yh-a8sy
# a8lh-Primary solid Tumor        tcga-yy-a8lh
# aapl-Primary solid Tumor        tcga-z5-aapl
#
# chd                                           bcr_patient_uuid vital_status  \
# cid
# aab1-Primary solid Tumor  75119d1a-93e5-4ae7-9d60-69ee929a0772         dead
# aab4-Primary solid Tumor  33833131-1482-42d5-9cf5-01cade540234        alive
# aab6-Primary solid Tumor  70797499-16e6-48cc-8ae4-1e692713dad3         dead
# aab8-Primary solid Tumor  2e8f90f4-aed3-43b0-985c-dfdc2581f24f        alive
# aab9-Primary solid Tumor  a5748656-5330-417a-8938-01f69ddb3576         dead
# ...                                                        ...          ...
# a89d-Solid Tissue Normal  b84b58c7-95b8-4162-8e61-414f8fe422c6        alive
# a89d-Primary solid Tumor  b84b58c7-95b8-4162-8e61-414f8fe422c6        alive
# a8sy-Primary solid Tumor  503d7e36-df78-428d-9971-09ff707645c2        alive
# a8lh-Primary solid Tumor  ede2e8a7-465e-4725-880d-519899aba0c0        alive
# aapl-Primary solid Tumor  6a4e10b6-e6c4-4210-ae4d-0d8e8d0cb3ec        alive
#
# chd                       days_to_death  days_to_last_followup  \
# cid
# aab1-Primary solid Tumor           66.0                    NaN
# aab4-Primary solid Tumor            NaN                  729.0
# aab6-Primary solid Tumor          293.0                    NaN
# aab8-Primary solid Tumor            NaN                   80.0
# aab9-Primary solid Tumor          627.0                    NaN
# ...                                 ...                    ...
# a89d-Solid Tissue Normal            NaN                  350.0
# a89d-Primary solid Tumor            NaN                  350.0
# a8sy-Primary solid Tumor            NaN                  388.0
# a8lh-Primary solid Tumor            NaN                 2016.0
# aapl-Primary solid Tumor            NaN                  467.0
#
# chd                       additional_studies adenocarcinoma_invasion  ...  \
# cid                                                                   ...
# aab1-Primary solid Tumor                 NaN                     yes  ...
# aab4-Primary solid Tumor                 NaN                     yes  ...
# aab6-Primary solid Tumor                 NaN                     yes  ...
# aab8-Primary solid Tumor                 NaN                     yes  ...
# aab9-Primary solid Tumor                 NaN                     yes  ...
# ...                                      ...                     ...  ...
# a89d-Solid Tissue Normal                 NaN                     yes  ...
# a89d-Primary solid Tumor                 NaN                     yes  ...
# a8sy-Primary solid Tumor                 NaN                     yes  ...
# a8lh-Primary solid Tumor                 NaN                     yes  ...
# aapl-Primary solid Tumor                 NaN                     yes  ...
#
# chd                       tobacco_smoking_history total_dose total_dose_units  \
# cid
# aab1-Primary solid Tumor                      3.0        NaN              NaN
# aab4-Primary solid Tumor                      5.0        NaN              NaN
# aab6-Primary solid Tumor                      NaN        NaN              NaN
# aab8-Primary solid Tumor                      NaN        NaN              NaN
# aab9-Primary solid Tumor                      1.0        NaN              NaN
# ...                                           ...        ...              ...
# a89d-Solid Tissue Normal                      1.0        NaN              NaN
# a89d-Primary solid Tumor                      1.0        NaN              NaN
# a8sy-Primary solid Tumor                      1.0        NaN              NaN
# a8lh-Primary solid Tumor                      2.0        NaN              NaN
# aapl-Primary solid Tumor                      1.0        NaN              NaN
#
# chd                       tumor_tissue_site tumor_type withdrawn  \
# cid
# aab1-Primary solid Tumor           pancreas    primary     false
# aab4-Primary solid Tumor           pancreas    primary     false
# aab6-Primary solid Tumor           pancreas    primary     false
# aab8-Primary solid Tumor           pancreas    primary     false
# aab9-Primary solid Tumor           pancreas    primary     false
# ...                                     ...        ...       ...
# a89d-Solid Tissue Normal           pancreas    primary     false
# a89d-Primary solid Tumor           pancreas    primary     false
# a8sy-Primary solid Tumor           pancreas    primary     false
# a8lh-Primary solid Tumor           pancreas    primary     false
# aapl-Primary solid Tumor           pancreas    primary     false
#
# chd                       year_of_dcc_upload year_of_form_completion  \
# cid
# aab1-Primary solid Tumor                2016                    2014
# aab4-Primary solid Tumor                2016                    2014
# aab6-Primary solid Tumor                2016                    2014
# aab8-Primary solid Tumor                2016                    2014
# aab9-Primary solid Tumor                2016                    2014
# ...                                      ...                     ...
# a89d-Solid Tissue Normal                2016                    2014
# a89d-Primary solid Tumor                2016                    2014
# a8sy-Primary solid Tumor                2016                    2014
# a8lh-Primary solid Tumor                2016                    2014
# aapl-Primary solid Tumor                2016                    2014
#
# chd                      year_of_initial_pathologic_diagnosis  \
# cid
# aab1-Primary solid Tumor                               2012.0
# aab4-Primary solid Tumor                               2012.0
# aab6-Primary solid Tumor                               2012.0
# aab8-Primary solid Tumor                               2012.0
# aab9-Primary solid Tumor                               2012.0
# ...                                                       ...
# a89d-Solid Tissue Normal                               2013.0
# a89d-Primary solid Tumor                               2013.0
# a8sy-Primary solid Tumor                               2011.0
# a8lh-Primary solid Tumor                               2009.0
# aapl-Primary solid Tumor                               2013.0
#
# chd                      year_of_tobacco_smoking_onset
# cid
# aab1-Primary solid Tumor                        1962.0
# aab4-Primary solid Tumor                           NaN
# aab6-Primary solid Tumor                           NaN
# aab8-Primary solid Tumor                           NaN
# aab9-Primary solid Tumor                           NaN
# ...                                                ...
# a89d-Solid Tissue Normal                           NaN
# a89d-Primary solid Tumor                           NaN
# a8sy-Primary solid Tumor                           NaN
# a8lh-Primary solid Tumor                        1963.0
# aapl-Primary solid Tumor                           NaN
#
# [183 rows x 124 columns]

# %%
data.data_df    # This is the dataframe consist of RNA seq in rows and person id(cid) in columns
# Out:
# cid        aab1-Primary solid Tumor  aab4-Primary solid Tumor  \
# rid
# SLC35E2                        7.45                       8.1
# A1BG                           6.40                       5.8
# A1CF                           4.70                       5.7
# A2BP1                         -1.00                       1.1
# A2LD1                          7.50                       6.8
# ...                             ...                       ...
# ZYG11B                         9.20                       9.3
# ZYX                           12.90                      12.4
# ZZEF1                         10.10                       9.8
# ZZZ3                           9.30                       8.9
# psiTPTE22                      5.50                       4.5
#
# cid        aab6-Primary solid Tumor  aab8-Primary solid Tumor  \
# rid
# SLC35E2                         7.2                       8.0
# A1BG                            6.4                       5.8
# A1CF                            3.0                       5.1
# A2BP1                           NaN                       NaN
# A2LD1                           7.3                       7.5
# ...                             ...                       ...
# ZYG11B                          9.4                       9.4
# ZYX                            13.5                      12.5
# ZZEF1                           9.8                       9.7
# ZZZ3                            9.2                       9.3
# psiTPTE22                       4.7                       6.4
#
# cid        aab9-Primary solid Tumor  aaba-Primary solid Tumor  \
# rid
# SLC35E2                        7.65                       8.1
# A1BG                           6.70                       6.6
# A1CF                           4.40                       4.2
# A2BP1                          0.10                       NaN
# A2LD1                          7.40                       6.6
# ...                             ...                       ...
# ZYG11B                         9.30                       9.9
# ZYX                           13.00                      12.2
# ZZEF1                         10.10                      10.4
# ZZZ3                           9.20                       9.6
# psiTPTE22                      4.90                       5.0
#
# cid        aabe-Primary solid Tumor  aabf-Primary solid Tumor  \
# rid
# SLC35E2                         8.2                       8.2
# A1BG                            6.3                       6.5
# A1CF                            1.6                       6.8
# A2BP1                           NaN                       1.7
# A2LD1                           7.1                       6.8
# ...                             ...                       ...
# ZYG11B                          9.1                       9.5
# ZYX                            12.9                      12.6
# ZZEF1                           9.7                      10.6
# ZZZ3                            8.9                       9.8
# psiTPTE22                       5.6                       5.1
#
# cid        aabh-Primary solid Tumor  aabi-Primary solid Tumor  ...  \
# rid                                                            ...
# SLC35E2                        7.55                      8.45  ...
# A1BG                           5.70                      6.30  ...
# A1CF                           6.00                       NaN  ...
# A2BP1                          0.40                     -1.50  ...
# A2LD1                          8.00                      5.80  ...
# ...                             ...                       ...  ...
# ZYG11B                         8.90                      8.30  ...
# ZYX                           12.70                     12.50  ...
# ZZEF1                         10.00                      9.90  ...
# ZZZ3                           8.80                      8.60  ...
# psiTPTE22                      4.60                      3.60  ...
#
# cid        aauh-Primary solid Tumor  aaui-Primary solid Tumor  \
# rid
# SLC35E2                        8.45                      7.95
# A1BG                           7.10                      7.10
# A1CF                           5.40                      6.40
# A2BP1                          3.50                      1.30
# A2LD1                          6.50                      7.30
# ...                             ...                       ...
# ZYG11B                         9.70                      9.20
# ZYX                           12.40                     12.60
# ZZEF1                         10.60                      9.90
# ZZZ3                           9.60                      9.00
# psiTPTE22                      6.00                      4.90
#
# cid        aaul-Primary solid Tumor  a8t3-Primary solid Tumor  \
# rid
# SLC35E2                         8.3                      8.05
# A1BG                            6.7                      7.00
# A1CF                            6.5                      4.40
# A2BP1                          -0.3                       NaN
# A2LD1                           6.1                      6.70
# ...                             ...                       ...
# ZYG11B                          9.5                      9.50
# ZYX                            13.5                     12.50
# ZZEF1                           9.8                     10.30
# ZZZ3                            9.0                      9.50
# psiTPTE22                       5.3                      5.60
#
# cid        a8t5-Primary solid Tumor  a89d-Solid Tissue Normal  \
# rid
# SLC35E2                         8.2                      7.25
# A1BG                            6.9                      7.10
# A1CF                            3.3                      3.60
# A2BP1                           2.1                      2.00
# A2LD1                           6.5                      6.70
# ...                             ...                       ...
# ZYG11B                          9.4                      9.40
# ZYX                            12.7                     13.60
# ZZEF1                          10.4                     10.20
# ZZZ3                            9.2                      8.50
# psiTPTE22                       6.1                      7.20
#
# cid        a89d-Primary solid Tumor  a8sy-Primary solid Tumor  \
# rid
# SLC35E2                         7.4                      7.35
# A1BG                            7.3                      7.90
# A1CF                            6.2                      1.20
# A2BP1                           0.0                       NaN
# A2LD1                           6.7                      6.50
# ...                             ...                       ...
# ZYG11B                          9.6                      9.20
# ZYX                            13.1                     13.20
# ZZEF1                           9.9                      9.80
# ZZZ3                            8.8                      8.60
# psiTPTE22                       5.1                      5.90
#
# cid        a8lh-Primary solid Tumor  aapl-Primary solid Tumor
# rid
# SLC35E2                         7.2                      9.05
# A1BG                            6.0                      6.90
# A1CF                            4.9                      2.00
# A2BP1                           2.0                       NaN
# A2LD1                           6.9                      6.70
# ...                             ...                       ...
# ZYG11B                          8.3                      9.50
# ZYX                            12.3                     12.30
# ZZEF1                           9.6                     10.90
# ZZZ3                            8.4                      9.40
# psiTPTE22                       2.4                      5.40
#
# [18465 rows x 183 columns]

# %% [markdown]
# ### Creating separate dataframe of the above stuffs so that we can perform further data analysis on them

# %%
col_data = data.col_metadata_df 
rna_data = data.data_df

# %%
# Lets see col_data

# %%
print(f'The shape of column metadata is { col_data.shape }')
# Out:
# The shape of column metadata is (183, 124)

# %%
# This means the number of participants is 183 because they are present in rows and number of info features of participant is
# 124 (column) because (row x column) = (183, 124)

# %%
nan_col_data = pd.DataFrame(data = col_data.isna().sum()
             , columns = ['Total'])

# %%
nan_col_data.sort_values(['Total'],ascending=False) # Some features are NAN for all 183 values
# Out:
#                            Total
# chd
# secondary_pattern            183
# total_dose                   183
# masaoka_stage                183
# clinical_m                   183
# clinical_n                   183
# ...                          ...
# month_of_dcc_upload            0
# month_of_form_completion       0
# neoplasm_histologic_grade      0
# other_dx                       0
# informed_consent_verified      0
#
# [124 rows x 1 columns]

# %%
features_drop_col = nan_col_data[nan_col_data.Total == 183]

# %%
features_drop_col.index
# Out:
# Index(['additional_studies', 'b_symptoms', 'clinical_m', 'clinical_n',
#        'clinical_stage', 'clinical_t', 'course_number', 'days_to_psa', 'drugs',
#        'extranodal_involvement', 'follow_ups', 'gleason_score', 'hiv_status',
#        'igcccg_stage', 'masaoka_stage',
#        'mononucleotide_marker_panel_analysis_status', 'number_cycles',
#        'prescribed_dose', 'prescribed_dose_units', 'primary_pattern',
#        'psa_value', 'radiation_type_notes', 'radiations', 'regimen_number',
#        'route_of_administration', 'secondary_pattern', 'serum_markers',
#        'tertiary_pattern', 'therapy_type_notes', 'total_dose',
#        'total_dose_units'],
#       dtype='object', name='chd')

# %%
col_data = col_data.drop(features_drop_col.index, axis=1)

# %%
print(f'The shape of column metadata is { col_data.shape }')
# Out:
# The shape of column metadata is (183, 93)

# %%
print(f'The shape of column metadata is { rna_data.shape }')
# Out:
# The shape of column metadata is (18465, 183)

# %%
rna_data = rna_data.T

# %%
nan_rna_data = pd.DataFrame(data = rna_data.isna().sum()
             , columns = ['Total'])

# %%
nan_rna_data
# Out:
#            Total
# rid
# SLC35E2        0
# A1BG           0
# A1CF           2
# A2BP1         42
# A2LD1          0
# ...          ...
# ZYG11B         0
# ZYX            0
# ZZEF1          0
# ZZZ3           0
# psiTPTE22      1
#
# [18465 rows x 1 columns]

# %%
nan_rna_data.sort_values(['Total'],ascending=False)
# Out:
#             Total
# rid
# NCRNA00114    128
# DEFA4         128
# AIPL1         128
# HESRG         128
# SOX3          128
# ...           ...
# GTF3C5          0
# GTF3C6          0
# GTPBP10         0
# GTPBP1          0
# LOC441046       0
#
# [18465 rows x 1 columns]

# %%
count = 0
for num in rna_data.isna().sum().values:
    if num!=0 :
        count= count+1
print(count)
# Out:
# 4367

# %%
rna_data = rna_data.T
rna_data = rna_data.dropna()

# %%
rna_data
# Out:
# cid      aab1-Primary solid Tumor  aab4-Primary solid Tumor  \
# rid
# SLC35E2                      7.45                       8.1
# A1BG                         6.40                       5.8
# A2LD1                        7.50                       6.8
# A2M                         14.30                      14.0
# A4GALT                      10.60                      10.2
# ...                           ...                       ...
# ZXDC                         9.90                      10.0
# ZYG11B                       9.20                       9.3
# ZYX                         12.90                      12.4
# ZZEF1                       10.10                       9.8
# ZZZ3                         9.30                       8.9
#
# cid      aab6-Primary solid Tumor  aab8-Primary solid Tumor  \
# rid
# SLC35E2                       7.2                       8.0
# A1BG                          6.4                       5.8
# A2LD1                         7.3                       7.5
# A2M                          13.1                      13.8
# A4GALT                       10.1                       8.6
# ...                           ...                       ...
# ZXDC                         10.0                       9.7
# ZYG11B                        9.4                       9.4
# ZYX                          13.5                      12.5
# ZZEF1                         9.8                       9.7
# ZZZ3                          9.2                       9.3
#
# cid      aab9-Primary solid Tumor  aaba-Primary solid Tumor  \
# rid
# SLC35E2                      7.65                       8.1
# A1BG                         6.70                       6.6
# A2LD1                        7.40                       6.6
# A2M                         14.60                      13.3
# A4GALT                      10.10                       9.3
# ...                           ...                       ...
# ZXDC                         9.90                      10.6
# ZYG11B                       9.30                       9.9
# ZYX                         13.00                      12.2
# ZZEF1                       10.10                      10.4
# ZZZ3                         9.20                       9.6
#
# cid      aabe-Primary solid Tumor  aabf-Primary solid Tumor  \
# rid
# SLC35E2                       8.2                       8.2
# A1BG                          6.3                       6.5
# A2LD1                         7.1                       6.8
# A2M                          13.4                      14.2
# A4GALT                        9.5                       8.4
# ...                           ...                       ...
# ZXDC                         10.1                       9.9
# ZYG11B                        9.1                       9.5
# ZYX                          12.9                      12.6
# ZZEF1                         9.7                      10.6
# ZZZ3                          8.9                       9.8
#
# cid      aabh-Primary solid Tumor  aabi-Primary solid Tumor  ...  \
# rid                                                          ...
# SLC35E2                      7.55                      8.45  ...
# A1BG                         5.70                      6.30  ...
# A2LD1                        8.00                      5.80  ...
# A2M                         13.90                     11.90  ...
# A4GALT                       8.40                      7.90  ...
# ...                           ...                       ...  ...
# ZXDC                         9.80                     10.70  ...
# ZYG11B                       8.90                      8.30  ...
# ZYX                         12.70                     12.50  ...
# ZZEF1                       10.00                      9.90  ...
# ZZZ3                         8.80                      8.60  ...
#
# cid      aauh-Primary solid Tumor  aaui-Primary solid Tumor  \
# rid
# SLC35E2                      8.45                      7.95
# A1BG                         7.10                      7.10
# A2LD1                        6.50                      7.30
# A2M                         14.50                     14.30
# A4GALT                       9.10                      9.50
# ...                           ...                       ...
# ZXDC                        10.10                     10.10
# ZYG11B                       9.70                      9.20
# ZYX                         12.40                     12.60
# ZZEF1                       10.60                      9.90
# ZZZ3                         9.60                      9.00
#
# cid      aaul-Primary solid Tumor  a8t3-Primary solid Tumor  \
# rid
# SLC35E2                       8.3                      8.05
# A1BG                          6.7                      7.00
# A2LD1                         6.1                      6.70
# A2M                          14.5                     14.20
# A4GALT                       10.0                      9.50
# ...                           ...                       ...
# ZXDC                          9.9                     10.10
# ZYG11B                        9.5                      9.50
# ZYX                          13.5                     12.50
# ZZEF1                         9.8                     10.30
# ZZZ3                          9.0                      9.50
#
# cid      a8t5-Primary solid Tumor  a89d-Solid Tissue Normal  \
# rid
# SLC35E2                       8.2                      7.25
# A1BG                          6.9                      7.10
# A2LD1                         6.5                      6.70
# A2M                          14.3                     14.90
# A4GALT                        9.1                     10.50
# ...                           ...                       ...
# ZXDC                          9.8                      9.50
# ZYG11B                        9.4                      9.40
# ZYX                          12.7                     13.60
# ZZEF1                        10.4                     10.20
# ZZZ3                          9.2                      8.50
#
# cid      a89d-Primary solid Tumor  a8sy-Primary solid Tumor  \
# rid
# SLC35E2                       7.4                      7.35
# A1BG                          7.3                      7.90
# A2LD1                         6.7                      6.50
# A2M                          14.5                     13.00
# A4GALT                        9.8                     10.80
# ...                           ...                       ...
# ZXDC                          9.5                      9.40
# ZYG11B                        9.6                      9.20
# ZYX                          13.1                     13.20
# ZZEF1                         9.9                      9.80
# ZZZ3                          8.8                      8.60
#
# cid      a8lh-Primary solid Tumor  aapl-Primary solid Tumor
# rid
# SLC35E2                       7.2                      9.05
# A1BG                          6.0                      6.90
# A2LD1                         6.9                      6.70
# A2M                          12.1                     13.30
# A4GALT                        8.3                      9.00
# ...                           ...                       ...
# ZXDC                          9.5                     10.40
# ZYG11B                        8.3                      9.50
# ZYX                          12.3                     12.30
# ZZEF1                         9.6                     10.90
# ZZZ3                          8.4                      9.40
#
# [14098 rows x 183 columns]

# %%
print(f'The shape of column metadata is { rna_data.shape }')
# Out:
# The shape of column metadata is (14098, 183)

# %%
(col_data.T).index
# Out:
# Index(['participant_id', 'sample_type', 'mRNAseq_cluster',
#        'bcr_patient_barcode', 'bcr_patient_uuid', 'vital_status',
#        'days_to_death', 'days_to_last_followup', 'additional_studies',
#        'adenocarcinoma_invasion',
#        ...
#        'tobacco_smoking_history', 'total_dose', 'total_dose_units',
#        'tumor_tissue_site', 'tumor_type', 'withdrawn', 'year_of_dcc_upload',
#        'year_of_form_completion', 'year_of_initial_pathologic_diagnosis',
#        'year_of_tobacco_smoking_onset'],
#       dtype='object', name='chd', length=124)

# %%
col_data["histological_type_other"].str.find("neuroendocrine")
# Out:
# cid
# aab1-Primary solid Tumor   -1.0
# aab4-Primary solid Tumor   -1.0
# aab6-Primary solid Tumor    NaN
# aab8-Primary solid Tumor    NaN
# aab9-Primary solid Tumor    NaN
#                            ...
# a89d-Solid Tissue Normal    NaN
# a89d-Primary solid Tumor    NaN
# a8sy-Primary solid Tumor    NaN
# a8lh-Primary solid Tumor    NaN
# aapl-Primary solid Tumor    NaN
# Name: histological_type_other, Length: 183, dtype: float64

# %%
import math
for feature in list((col_data.T).index):
    try:
        for i in col_data[feature].str.find("neuroendocrine").values:  # String value
            if i!=-1 and math.isnan(i)!= True:
                print(feature)
    except:
        continue
# Out:
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other

# %%
import math
for feature in list((col_data.T).index):
    try:
        for i in col_data[feature].str.find("adenocarcinoma").values:  # String value
            if i!=-1 and math.isnan(i)!= True:
                print(feature)
    except:
        continue
# Out:
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other
# histological_type_other

# %%
# We should observe histological_type_other

# %%
col_data.histological_type_other.value_counts()s
# Out:
# adenocarcinoma, nos                                                         8
# neuroendocrine carcinoma nos                                                5
# invasive adenocarcinoma                                                     2
# poorly differentiated pancreatic adenocarcinoma                             2
# not specified                                                               1
# intraductal tubulopapillary neoplasm                                        1
# moderately differentiated ductal adenocarcinoma 60% + neuroendocrine 40%    1
# 82463 neuroendocrine carcinoma nos                                          1
# adenocarcinoma- nos                                                         1
# neuroendocrine                                                              1
# ductal and micropapillary                                                   1
# neuroendocrine carcinoma                                                    1
# invasive, well-differentiated                                               1
# poorly differentiated adenocarcinoma                                        1
# Name: histological_type_other, dtype: int64

# %%
col_data.histological_type.value_counts()
# Out:
# pancreas-adenocarcinoma ductal type                 150
# pancreas-adenocarcinoma-other subtype                27
# pancreas-colloid (mucinous non-cystic) carcinoma      4
# pancreas-undifferentiated carcinoma                   1
# Name: histological_type, dtype: int64

# %%
# real dataset

# %%
col_data_adenocarcinoma = col_data[col_data==""]

# %%
data.assemble_multi_index_df
# Out:
# <bound method GCToo.assemble_multi_index_df of <cmapPy.pandasGEXpress.GCToo.GCToo object at 0x00000156B4CC7108>>

# %%
data.col_metadata_df
# Out:
# chd                      participant_id          sample_type  mRNAseq_cluster  \
# cid
# aab1-Primary solid Tumor           aab1  Primary solid Tumor              1.0
# aab4-Primary solid Tumor           aab4  Primary solid Tumor              2.0
# aab6-Primary solid Tumor           aab6  Primary solid Tumor              3.0
# aab8-Primary solid Tumor           aab8  Primary solid Tumor              1.0
# aab9-Primary solid Tumor           aab9  Primary solid Tumor              4.0
# ...                                 ...                  ...              ...
# a89d-Solid Tissue Normal           a89d  Solid Tissue Normal              NaN
# a89d-Primary solid Tumor           a89d  Primary solid Tumor              2.0
# a8sy-Primary solid Tumor           a8sy  Primary solid Tumor              3.0
# a8lh-Primary solid Tumor           a8lh  Primary solid Tumor              1.0
# aapl-Primary solid Tumor           aapl  Primary solid Tumor              5.0
#
# chd                      bcr_patient_barcode  \
# cid
# aab1-Primary solid Tumor        tcga-2j-aab1
# aab4-Primary solid Tumor        tcga-2j-aab4
# aab6-Primary solid Tumor        tcga-2j-aab6
# aab8-Primary solid Tumor        tcga-2j-aab8
# aab9-Primary solid Tumor        tcga-2j-aab9
# ...                                      ...
# a89d-Solid Tissue Normal        tcga-yb-a89d
# a89d-Primary solid Tumor        tcga-yb-a89d
# a8sy-Primary solid Tumor        tcga-yh-a8sy
# a8lh-Primary solid Tumor        tcga-yy-a8lh
# aapl-Primary solid Tumor        tcga-z5-aapl
#
# chd                                           bcr_patient_uuid vital_status  \
# cid
# aab1-Primary solid Tumor  75119d1a-93e5-4ae7-9d60-69ee929a0772         dead
# aab4-Primary solid Tumor  33833131-1482-42d5-9cf5-01cade540234        alive
# aab6-Primary solid Tumor  70797499-16e6-48cc-8ae4-1e692713dad3         dead
# aab8-Primary solid Tumor  2e8f90f4-aed3-43b0-985c-dfdc2581f24f        alive
# aab9-Primary solid Tumor  a5748656-5330-417a-8938-01f69ddb3576         dead
# ...                                                        ...          ...
# a89d-Solid Tissue Normal  b84b58c7-95b8-4162-8e61-414f8fe422c6        alive
# a89d-Primary solid Tumor  b84b58c7-95b8-4162-8e61-414f8fe422c6        alive
# a8sy-Primary solid Tumor  503d7e36-df78-428d-9971-09ff707645c2        alive
# a8lh-Primary solid Tumor  ede2e8a7-465e-4725-880d-519899aba0c0        alive
# aapl-Primary solid Tumor  6a4e10b6-e6c4-4210-ae4d-0d8e8d0cb3ec        alive
#
# chd                       days_to_death  days_to_last_followup  \
# cid
# aab1-Primary solid Tumor           66.0                    NaN
# aab4-Primary solid Tumor            NaN                  729.0
# aab6-Primary solid Tumor          293.0                    NaN
# aab8-Primary solid Tumor            NaN                   80.0
# aab9-Primary solid Tumor          627.0                    NaN
# ...                                 ...                    ...
# a89d-Solid Tissue Normal            NaN                  350.0
# a89d-Primary solid Tumor            NaN                  350.0
# a8sy-Primary solid Tumor            NaN                  388.0
# a8lh-Primary solid Tumor            NaN                 2016.0
# aapl-Primary solid Tumor            NaN                  467.0
#
# chd                       additional_studies adenocarcinoma_invasion  ...  \
# cid                                                                   ...
# aab1-Primary solid Tumor                 NaN                     yes  ...
# aab4-Primary solid Tumor                 NaN                     yes  ...
# aab6-Primary solid Tumor                 NaN                     yes  ...
# aab8-Primary solid Tumor                 NaN                     yes  ...
# aab9-Primary solid Tumor                 NaN                     yes  ...
# ...                                      ...                     ...  ...
# a89d-Solid Tissue Normal                 NaN                     yes  ...
# a89d-Primary solid Tumor                 NaN                     yes  ...
# a8sy-Primary solid Tumor                 NaN                     yes  ...
# a8lh-Primary solid Tumor                 NaN                     yes  ...
# aapl-Primary solid Tumor                 NaN                     yes  ...
#
# chd                       tobacco_smoking_history total_dose total_dose_units  \
# cid
# aab1-Primary solid Tumor                      3.0        NaN              NaN
# aab4-Primary solid Tumor                      5.0        NaN              NaN
# aab6-Primary solid Tumor                      NaN        NaN              NaN
# aab8-Primary solid Tumor                      NaN        NaN              NaN
# aab9-Primary solid Tumor                      1.0        NaN              NaN
# ...                                           ...        ...              ...
# a89d-Solid Tissue Normal                      1.0        NaN              NaN
# a89d-Primary solid Tumor                      1.0        NaN              NaN
# a8sy-Primary solid Tumor                      1.0        NaN              NaN
# a8lh-Primary solid Tumor                      2.0        NaN              NaN
# aapl-Primary solid Tumor                      1.0        NaN              NaN
#
# chd                       tumor_tissue_site tumor_type withdrawn  \
# cid
# aab1-Primary solid Tumor           pancreas    primary     false
# aab4-Primary solid Tumor           pancreas    primary     false
# aab6-Primary solid Tumor           pancreas    primary     false
# aab8-Primary solid Tumor           pancreas    primary     false
# aab9-Primary solid Tumor           pancreas    primary     false
# ...                                     ...        ...       ...
# a89d-Solid Tissue Normal           pancreas    primary     false
# a89d-Primary solid Tumor           pancreas    primary     false
# a8sy-Primary solid Tumor           pancreas    primary     false
# a8lh-Primary solid Tumor           pancreas    primary     false
# aapl-Primary solid Tumor           pancreas    primary     false
#
# chd                       year_of_dcc_upload year_of_form_completion  \
# cid
# aab1-Primary solid Tumor                2016                    2014
# aab4-Primary solid Tumor                2016                    2014
# aab6-Primary solid Tumor                2016                    2014
# aab8-Primary solid Tumor                2016                    2014
# aab9-Primary solid Tumor                2016                    2014
# ...                                      ...                     ...
# a89d-Solid Tissue Normal                2016                    2014
# a89d-Primary solid Tumor                2016                    2014
# a8sy-Primary solid Tumor                2016                    2014
# a8lh-Primary solid Tumor                2016                    2014
# aapl-Primary solid Tumor                2016                    2014
#
# chd                      year_of_initial_pathologic_diagnosis  \
# cid
# aab1-Primary solid Tumor                               2012.0
# aab4-Primary solid Tumor                               2012.0
# aab6-Primary solid Tumor                               2012.0
# aab8-Primary solid Tumor                               2012.0
# aab9-Primary solid Tumor                               2012.0
# ...                                                       ...
# a89d-Solid Tissue Normal                               2013.0
# a89d-Primary solid Tumor                               2013.0
# a8sy-Primary solid Tumor                               2011.0
# a8lh-Primary solid Tumor                               2009.0
# aapl-Primary solid Tumor                               2013.0
#
# chd                      year_of_tobacco_smoking_onset
# cid
# aab1-Primary solid Tumor                        1962.0
# aab4-Primary solid Tumor                           NaN
# aab6-Primary solid Tumor                           NaN
# aab8-Primary solid Tumor                           NaN
# aab9-Primary solid Tumor                           NaN
# ...                                                ...
# a89d-Solid Tissue Normal                           NaN
# a89d-Primary solid Tumor                           NaN
# a8sy-Primary solid Tumor                           NaN
# a8lh-Primary solid Tumor                        1963.0
# aapl-Primary solid Tumor                           NaN
#
# [183 rows x 124 columns]

# %%
metadata= data.col_metadata_df

# %%
metadata['adenocarcinoma_invasion'].isna().sum()
# Out:
# 0

# %%
metadata['adenocarcinoma_invasion'].nunique()
# Out:
# 2

# %%
metadata['adenocarcinoma_invasion'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
metadata =  metadata[metadata.adenocarcinoma_invasion == 'yes']

# %%
metadata['adenocarcinoma_invasion'].unique()
# Out:
# array(['yes'], dtype=object)

# %%
metadata = metadata.set_index('participant_id').T

# %%
lists = metadata.index

# %%
for l in lists:
    if l.find("adenocarcinoma")!=-1:
        print(l)
# Out:
# adenocarcinoma_invasion

# %%
for l in lists:
    if l.find("neuroendocrine")!=-1:
        print(l)

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123 entries, sample_type to year_of_tobacco_smoking_onset
# Columns: 182 entries, aab1 to aapl
# dtypes: object(182)
# memory usage: 175.9+ KB

# %%
metadata.dtypes
# Out:
# participant_id
# aab1    object
# aab4    object
# aab6    object
# aab8    object
# aab9    object
#          ...
# a89d    object
# a89d    object
# a8sy    object
# a8lh    object
# aapl    object
# Length: 182, dtype: object

# %%
metadata.shape
# Out:
# (123, 182)

# %%
metadata.isna().sum()
# Out:
# participant_id
# aab1    49
# aab4    52
# aab6    58
# aab8    58
# aab9    51
#         ..
# a89d    51
# a89d    50
# a8sy    60
# a8lh    48
# aapl    60
# Length: 182, dtype: int64

# %%
data.data_df
# Out:
# cid        aab1-Primary solid Tumor  aab4-Primary solid Tumor  \
# rid
# SLC35E2                        7.45                       8.1
# A1BG                           6.40                       5.8
# A1CF                           4.70                       5.7
# A2BP1                         -1.00                       1.1
# A2LD1                          7.50                       6.8
# ...                             ...                       ...
# ZYG11B                         9.20                       9.3
# ZYX                           12.90                      12.4
# ZZEF1                         10.10                       9.8
# ZZZ3                           9.30                       8.9
# psiTPTE22                      5.50                       4.5
#
# cid        aab6-Primary solid Tumor  aab8-Primary solid Tumor  \
# rid
# SLC35E2                         7.2                       8.0
# A1BG                            6.4                       5.8
# A1CF                            3.0                       5.1
# A2BP1                           NaN                       NaN
# A2LD1                           7.3                       7.5
# ...                             ...                       ...
# ZYG11B                          9.4                       9.4
# ZYX                            13.5                      12.5
# ZZEF1                           9.8                       9.7
# ZZZ3                            9.2                       9.3
# psiTPTE22                       4.7                       6.4
#
# cid        aab9-Primary solid Tumor  aaba-Primary solid Tumor  \
# rid
# SLC35E2                        7.65                       8.1
# A1BG                           6.70                       6.6
# A1CF                           4.40                       4.2
# A2BP1                          0.10                       NaN
# A2LD1                          7.40                       6.6
# ...                             ...                       ...
# ZYG11B                         9.30                       9.9
# ZYX                           13.00                      12.2
# ZZEF1                         10.10                      10.4
# ZZZ3                           9.20                       9.6
# psiTPTE22                      4.90                       5.0
#
# cid        aabe-Primary solid Tumor  aabf-Primary solid Tumor  \
# rid
# SLC35E2                         8.2                       8.2
# A1BG                            6.3                       6.5
# A1CF                            1.6                       6.8
# A2BP1                           NaN                       1.7
# A2LD1                           7.1                       6.8
# ...                             ...                       ...
# ZYG11B                          9.1                       9.5
# ZYX                            12.9                      12.6
# ZZEF1                           9.7                      10.6
# ZZZ3                            8.9                       9.8
# psiTPTE22                       5.6                       5.1
#
# cid        aabh-Primary solid Tumor  aabi-Primary solid Tumor  ...  \
# rid                                                            ...
# SLC35E2                        7.55                      8.45  ...
# A1BG                           5.70                      6.30  ...
# A1CF                           6.00                       NaN  ...
# A2BP1                          0.40                     -1.50  ...
# A2LD1                          8.00                      5.80  ...
# ...                             ...                       ...  ...
# ZYG11B                         8.90                      8.30  ...
# ZYX                           12.70                     12.50  ...
# ZZEF1                         10.00                      9.90  ...
# ZZZ3                           8.80                      8.60  ...
# psiTPTE22                      4.60                      3.60  ...
#
# cid        aauh-Primary solid Tumor  aaui-Primary solid Tumor  \
# rid
# SLC35E2                        8.45                      7.95
# A1BG                           7.10                      7.10
# A1CF                           5.40                      6.40
# A2BP1                          3.50                      1.30
# A2LD1                          6.50                      7.30
# ...                             ...                       ...
# ZYG11B                         9.70                      9.20
# ZYX                           12.40                     12.60
# ZZEF1                         10.60                      9.90
# ZZZ3                           9.60                      9.00
# psiTPTE22                      6.00                      4.90
#
# cid        aaul-Primary solid Tumor  a8t3-Primary solid Tumor  \
# rid
# SLC35E2                         8.3                      8.05
# A1BG                            6.7                      7.00
# A1CF                            6.5                      4.40
# A2BP1                          -0.3                       NaN
# A2LD1                           6.1                      6.70
# ...                             ...                       ...
# ZYG11B                          9.5                      9.50
# ZYX                            13.5                     12.50
# ZZEF1                           9.8                     10.30
# ZZZ3                            9.0                      9.50
# psiTPTE22                       5.3                      5.60
#
# cid        a8t5-Primary solid Tumor  a89d-Solid Tissue Normal  \
# rid
# SLC35E2                         8.2                      7.25
# A1BG                            6.9                      7.10
# A1CF                            3.3                      3.60
# A2BP1                           2.1                      2.00
# A2LD1                           6.5                      6.70
# ...                             ...                       ...
# ZYG11B                          9.4                      9.40
# ZYX                            12.7                     13.60
# ZZEF1                          10.4                     10.20
# ZZZ3                            9.2                      8.50
# psiTPTE22                       6.1                      7.20
#
# cid        a89d-Primary solid Tumor  a8sy-Primary solid Tumor  \
# rid
# SLC35E2                         7.4                      7.35
# A1BG                            7.3                      7.90
# A1CF                            6.2                      1.20
# A2BP1                           0.0                       NaN
# A2LD1                           6.7                      6.50
# ...                             ...                       ...
# ZYG11B                          9.6                      9.20
# ZYX                            13.1                     13.20
# ZZEF1                           9.9                      9.80
# ZZZ3                            8.8                      8.60
# psiTPTE22                       5.1                      5.90
#
# cid        a8lh-Primary solid Tumor  aapl-Primary solid Tumor
# rid
# SLC35E2                         7.2                      9.05
# A1BG                            6.0                      6.90
# A1CF                            4.9                      2.00
# A2BP1                           2.0                       NaN
# A2LD1                           6.9                      6.70
# ...                             ...                       ...
# ZYG11B                          8.3                      9.50
# ZYX                            12.3                     12.30
# ZZEF1                           9.6                     10.90
# ZZZ3                            8.4                      9.40
# psiTPTE22                       2.4                      5.40
#
# [18465 rows x 183 columns]

# %%
genedata = data.data_df

# %%
genedata.index
# Out:
# Index(['SLC35E2', 'A1BG', 'A1CF', 'A2BP1', 'A2LD1', 'A2ML1', 'A2M', 'A4GALT',
#        'A4GNT', 'AAA1',
#        ...
#        'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B', 'ZYX', 'ZZEF1',
#        'ZZZ3', 'psiTPTE22'],
#       dtype='object', name='rid', length=18465)

# %%
len(genedata.index)
# Out:
# 18465

# %%
genedata = genedata.T

# %%
genedata.index
# Out:
# Index(['aab1-Primary solid Tumor', 'aab4-Primary solid Tumor',
#        'aab6-Primary solid Tumor', 'aab8-Primary solid Tumor',
#        'aab9-Primary solid Tumor', 'aaba-Primary solid Tumor',
#        'aabe-Primary solid Tumor', 'aabf-Primary solid Tumor',
#        'aabh-Primary solid Tumor', 'aabi-Primary solid Tumor',
#        ...
#        'aauh-Primary solid Tumor', 'aaui-Primary solid Tumor',
#        'aaul-Primary solid Tumor', 'a8t3-Primary solid Tumor',
#        'a8t5-Primary solid Tumor', 'a89d-Solid Tissue Normal',
#        'a89d-Primary solid Tumor', 'a8sy-Primary solid Tumor',
#        'a8lh-Primary solid Tumor', 'aapl-Primary solid Tumor'],
#       dtype='object', name='cid', length=183)

# %%
genedata
# Out:
# rid                       SLC35E2  A1BG  A1CF  A2BP1  A2LD1  A2ML1   A2M  \
# cid
# aab1-Primary solid Tumor     7.45   6.4   4.7   -1.0    7.5    6.4  14.3
# aab4-Primary solid Tumor     8.10   5.8   5.7    1.1    6.8    NaN  14.0
# aab6-Primary solid Tumor     7.20   6.4   3.0    NaN    7.3   10.8  13.1
# aab8-Primary solid Tumor     8.00   5.8   5.1    NaN    7.5    4.1  13.8
# aab9-Primary solid Tumor     7.65   6.7   4.4    0.1    7.4    9.3  14.6
# ...                           ...   ...   ...    ...    ...    ...   ...
# a89d-Solid Tissue Normal     7.25   7.1   3.6    2.0    6.7    1.0  14.9
# a89d-Primary solid Tumor     7.40   7.3   6.2    0.0    6.7    2.8  14.5
# a8sy-Primary solid Tumor     7.35   7.9   1.2    NaN    6.5   10.5  13.0
# a8lh-Primary solid Tumor     7.20   6.0   4.9    2.0    6.9    3.1  12.1
# aapl-Primary solid Tumor     9.05   6.9   2.0    NaN    6.7    5.1  13.3
#
# rid                       A4GALT  A4GNT  AAA1  ...  ZWINT  ZXDA  ZXDB  ZXDC  \
# cid                                            ...
# aab1-Primary solid Tumor    10.6    8.8   1.0  ...    8.6   6.2   9.0   9.9
# aab4-Primary solid Tumor    10.2    5.6  -1.2  ...    8.8   5.8   8.5  10.0
# aab6-Primary solid Tumor    10.1    0.2   0.2  ...    9.1   3.9   8.1  10.0
# aab8-Primary solid Tumor     8.6    3.2  -0.1  ...    8.9   5.2   8.5   9.7
# aab9-Primary solid Tumor    10.1    5.7   NaN  ...    8.4   5.9   8.6   9.9
# ...                          ...    ...   ...  ...    ...   ...   ...   ...
# a89d-Solid Tissue Normal    10.5    2.7   1.3  ...    7.8   5.3   8.4   9.5
# a89d-Primary solid Tumor     9.8    4.3   1.8  ...    7.9   5.3   8.8   9.5
# a8sy-Primary solid Tumor    10.8    0.8   NaN  ...    9.4   5.0   8.2   9.4
# a8lh-Primary solid Tumor     8.3    6.6   1.8  ...    8.8   5.4   8.7   9.5
# aapl-Primary solid Tumor     9.0    2.2   NaN  ...    9.1   6.3   8.9  10.4
#
# rid                       ZYG11A  ZYG11B   ZYX  ZZEF1  ZZZ3  psiTPTE22
# cid
# aab1-Primary solid Tumor     NaN     9.2  12.9   10.1   9.3        5.5
# aab4-Primary solid Tumor     NaN     9.3  12.4    9.8   8.9        4.5
# aab6-Primary solid Tumor    -0.8     9.4  13.5    9.8   9.2        4.7
# aab8-Primary solid Tumor     1.9     9.4  12.5    9.7   9.3        6.4
# aab9-Primary solid Tumor     0.1     9.3  13.0   10.1   9.2        4.9
# ...                          ...     ...   ...    ...   ...        ...
# a89d-Solid Tissue Normal     0.6     9.4  13.6   10.2   8.5        7.2
# a89d-Primary solid Tumor     NaN     9.6  13.1    9.9   8.8        5.1
# a8sy-Primary solid Tumor    -0.8     9.2  13.2    9.8   8.6        5.9
# a8lh-Primary solid Tumor     NaN     8.3  12.3    9.6   8.4        2.4
# aapl-Primary solid Tumor     3.1     9.5  12.3   10.9   9.4        5.4
#
# [183 rows x 18465 columns]

# %%
genedata = genedata.fillna(genedata.mean())

# %%
genedata
# Out:
# rid                       SLC35E2  A1BG  A1CF     A2BP1  A2LD1      A2ML1  \
# cid
# aab1-Primary solid Tumor     7.45   6.4   4.7 -1.000000    7.5   6.400000
# aab4-Primary solid Tumor     8.10   5.8   5.7  1.100000    6.8   4.232691
# aab6-Primary solid Tumor     7.20   6.4   3.0  0.441844    7.3  10.800000
# aab8-Primary solid Tumor     8.00   5.8   5.1  0.441844    7.5   4.100000
# aab9-Primary solid Tumor     7.65   6.7   4.4  0.100000    7.4   9.300000
# ...                           ...   ...   ...       ...    ...        ...
# a89d-Solid Tissue Normal     7.25   7.1   3.6  2.000000    6.7   1.000000
# a89d-Primary solid Tumor     7.40   7.3   6.2  0.000000    6.7   2.800000
# a8sy-Primary solid Tumor     7.35   7.9   1.2  0.441844    6.5  10.500000
# a8lh-Primary solid Tumor     7.20   6.0   4.9  2.000000    6.9   3.100000
# aapl-Primary solid Tumor     9.05   6.9   2.0  0.441844    6.7   5.100000
#
# rid                        A2M  A4GALT  A4GNT    AAA1  ...  ZWINT  ZXDA  ZXDB  \
# cid                                                    ...
# aab1-Primary solid Tumor  14.3    10.6    8.8  1.0000  ...    8.6   6.2   9.0
# aab4-Primary solid Tumor  14.0    10.2    5.6 -1.2000  ...    8.8   5.8   8.5
# aab6-Primary solid Tumor  13.1    10.1    0.2  0.2000  ...    9.1   3.9   8.1
# aab8-Primary solid Tumor  13.8     8.6    3.2 -0.1000  ...    8.9   5.2   8.5
# aab9-Primary solid Tumor  14.6    10.1    5.7  0.7872  ...    8.4   5.9   8.6
# ...                        ...     ...    ...     ...  ...    ...   ...   ...
# a89d-Solid Tissue Normal  14.9    10.5    2.7  1.3000  ...    7.8   5.3   8.4
# a89d-Primary solid Tumor  14.5     9.8    4.3  1.8000  ...    7.9   5.3   8.8
# a8sy-Primary solid Tumor  13.0    10.8    0.8  0.7872  ...    9.4   5.0   8.2
# a8lh-Primary solid Tumor  12.1     8.3    6.6  1.8000  ...    8.8   5.4   8.7
# aapl-Primary solid Tumor  13.3     9.0    2.2  0.7872  ...    9.1   6.3   8.9
#
# rid                       ZXDC    ZYG11A  ZYG11B   ZYX  ZZEF1  ZZZ3  psiTPTE22
# cid
# aab1-Primary solid Tumor   9.9  0.327143     9.2  12.9   10.1   9.3        5.5
# aab4-Primary solid Tumor  10.0  0.327143     9.3  12.4    9.8   8.9        4.5
# aab6-Primary solid Tumor  10.0 -0.800000     9.4  13.5    9.8   9.2        4.7
# aab8-Primary solid Tumor   9.7  1.900000     9.4  12.5    9.7   9.3        6.4
# aab9-Primary solid Tumor   9.9  0.100000     9.3  13.0   10.1   9.2        4.9
# ...                        ...       ...     ...   ...    ...   ...        ...
# a89d-Solid Tissue Normal   9.5  0.600000     9.4  13.6   10.2   8.5        7.2
# a89d-Primary solid Tumor   9.5  0.327143     9.6  13.1    9.9   8.8        5.1
# a8sy-Primary solid Tumor   9.4 -0.800000     9.2  13.2    9.8   8.6        5.9
# a8lh-Primary solid Tumor   9.5  0.327143     8.3  12.3    9.6   8.4        2.4
# aapl-Primary solid Tumor  10.4  3.100000     9.5  12.3   10.9   9.4        5.4
#
# [183 rows x 18465 columns]

# %%
x = genedata.values

# %%
from sklearn.decomposition import PCA
import pandas as pd
pca = PCA(n_components=130)
principalComponents = pca.fit_transform(x)

# %%
principalDf
# Out:
#      principal component 1  principal component 2
# 0               -32.719597             -10.276606
# 1                -2.929201              -3.829057
# 2               -29.499166              15.751595
# 3               -43.193668             -10.928938
# 4                21.999323             -19.225464
# ..                     ...                    ...
# 178              14.157618             -49.164345
# 179               6.103239             -18.429773
# 180             -68.055107             -10.208421
# 181             -88.629486              53.003326
# 182              14.768301             -30.525696
#
# [183 rows x 2 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,6)

fig, ax = plt.subplots()
xi = np.arange(1, 131, step=1)
y = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, y, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 121, step=10)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.show()

# %%
import seaborn as sns

# %%
sns.scatterplot(data=principalDf, x="principal component 1", y="principal component 2")
# Out:
# <AxesSubplot:xlabel='principal component 1', ylabel='principal component 2'>

# %%
genelist =  (genedata.T).index

# %%
for l in genelist:
    if l.find("IFN")!=-1:
        print(l)
# Out:
# IFNA13
# IFNA1
# IFNAR1
# IFNAR2
# IFNE
# IFNGR1
# IFNGR2
# IFNG

# %%
genedata.index
# Out:
# Index(['aab1-Primary solid Tumor', 'aab4-Primary solid Tumor',
#        'aab6-Primary solid Tumor', 'aab8-Primary solid Tumor',
#        'aab9-Primary solid Tumor', 'aaba-Primary solid Tumor',
#        'aabe-Primary solid Tumor', 'aabf-Primary solid Tumor',
#        'aabh-Primary solid Tumor', 'aabi-Primary solid Tumor',
#        ...
#        'aauh-Primary solid Tumor', 'aaui-Primary solid Tumor',
#        'aaul-Primary solid Tumor', 'a8t3-Primary solid Tumor',
#        'a8t5-Primary solid Tumor', 'a89d-Solid Tissue Normal',
#        'a89d-Primary solid Tumor', 'a8sy-Primary solid Tumor',
#        'a8lh-Primary solid Tumor', 'aapl-Primary solid Tumor'],
#       dtype='object', name='cid', length=183)

# %%
ifns = (genedata.T).loc[['IFNA13','IFNA1','IFNAR1','IFNAR2','IFNE','IFNGR1','IFNGR2','IFNG']]

# %%
ifns = ifns.T

# %%
(ifns.T).isna().sum()
# Out:
# rid
# IFNA13    0
# IFNA1     0
# IFNAR1    0
# IFNAR2    0
# IFNE      0
# IFNGR1    0
# IFNGR2    0
# IFNG      0
# dtype: int64

# %%
x = (ifns.T).values

# %%
x
# Out:
# array([[ 0.20493825, -0.03188407, 10.8       , ..., 10.9       ,
#         11.8       ,  1.        ],
#        [-1.2       , -1.2       , 11.1       , ..., 11.5       ,
#         12.4       , -0.2       ],
#        [ 2.4       ,  1.8       , 10.6       , ..., 10.5       ,
#         11.2       ,  0.2       ],
#        ...,
#        [ 0.20493825, -0.03188407, 10.7       , ..., 11.1       ,
#         12.1       ,  0.2       ],
#        [-0.2       , -0.2       , 10.7       , ..., 10.3       ,
#         12.7       ,  0.9351352 ],
#        [ 0.20493825, -0.03188407, 10.7       , ..., 11.5       ,
#         11.5       ,  3.6       ]], dtype=float32)

# %%
from sklearn.decomposition import PCA
import pandas as pd
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
principalDf
# Out:
#      principal component 1  principal component 2
# 0                 1.158581               0.082478
# 1                 1.314231              -1.039679
# 2                 3.876942              -0.692970
# 3                 3.286706              -0.948471
# 4                 1.981355               0.987170
# ..                     ...                    ...
# 178               1.348434               0.731791
# 179               0.805763              -1.923021
# 180               1.475753              -0.685790
# 181               2.814993               0.049316
# 182              -2.673291               2.632390
#
# [183 rows x 2 columns]

# %%
sns.scatterplot(data=principalDf, x="principal component 1", y="principal component 2")
# Out:
# <AxesSubplot:xlabel='principal component 1', ylabel='principal component 2'>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
import pandas as pd
import seaborn as sns
from sklearn.datasets.samples_generator import (make_blobs,
                                                make_circles,
                                                make_moons)
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score

from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# C:\Users\chand\anaconda3\envs\AI\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.cluster import KMeans, SpectralClustering

# %%
ifns
# Out:
# rid                         IFNA13     IFNA1  IFNAR1  IFNAR2  IFNE  IFNGR1  \
# cid
# aab1-Primary solid Tumor  0.204938 -0.031884    10.8     9.3   4.6    10.9
# aab4-Primary solid Tumor -1.200000 -1.200000    11.1     9.9   5.1    11.5
# aab6-Primary solid Tumor  2.400000  1.800000    10.6     8.3   6.8    10.5
# aab8-Primary solid Tumor  1.900000  1.500000    10.7     9.0   6.3    10.8
# aab9-Primary solid Tumor  1.700000  2.100000    10.8     9.3   5.1    12.6
# ...                            ...       ...     ...     ...   ...     ...
# a89d-Solid Tissue Normal  0.600000 -1.000000    10.8     9.4   4.9    11.5
# a89d-Primary solid Tumor  0.204938 -0.031884    10.7     9.0   4.2    11.0
# a8sy-Primary solid Tumor  0.204938 -0.031884    10.7     9.2   4.9    11.1
# a8lh-Primary solid Tumor -0.200000 -0.200000    10.7    10.1   6.3    10.3
# aapl-Primary solid Tumor  0.204938 -0.031884    10.7     9.7   0.8    11.5
#
# rid                       IFNGR2      IFNG
# cid
# aab1-Primary solid Tumor    11.8  1.000000
# aab4-Primary solid Tumor    12.4 -0.200000
# aab6-Primary solid Tumor    11.2  0.200000
# aab8-Primary solid Tumor    11.8 -0.100000
# aab9-Primary solid Tumor    11.4  1.700000
# ...                          ...       ...
# a89d-Solid Tissue Normal    11.8  1.600000
# a89d-Primary solid Tumor    11.6 -1.000000
# a8sy-Primary solid Tumor    12.1  0.200000
# a8lh-Primary solid Tumor    12.7  0.935135
# aapl-Primary solid Tumor    11.5  3.600000
#
# [183 rows x 8 columns]

# %%
# Standardize the data
X_std = StandardScaler().fit_transform(ifns)

# Run local implementation of kmeans
from sklearn.cluster import KMeans
Kmean = KMeans(n_clusters=2)
Kmean.fit(X_std)
# Out:
# KMeans(n_clusters=2)

# %%
sns.lmplot(x='Top10perc',y='S.F.Ratio',data=labeledColleges,hue='labels',fit_reg=False)
